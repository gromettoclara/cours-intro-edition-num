# %% [markdown]
# # Chapitre 3 : fabriquer (facilement) des documents structurés

# %% [markdown]
# # I. Encoder en XML-TEI

# %% [markdown]
# ## Qu’est-ce que la TEI ?
#
# > "La TEI a été d’abord développée, il y a plus de trente ans, comme un projet de recherche dans le champ alors émergent du « Humanities computing ». L’idée originelle était de proposer un ensemble de recommandations sur la façon dont les chercheurs devraient créer des ressources textuelles « lisibles par ordinateur », qui soient adaptées aux besoins de la recherche – dans la mesure où un consensus existait sur le sujet –, mais qui soient également extensibles, puisque ces besoins changent et évoluent." (Burnard, Lou. 2015. « La TEI et le XML ». In *Qu’est-ce que la Text Encoding Initiative ? Encyclopédie numérique.* OpenEdition Press. https://doi.org/10.4000/books.oep.1298.)

# %% [markdown]
# ## Définition
#
# TEI est un set de balises prédéfini et documenté dans les TEI guidelines qui permet de procéder à une description `scientifique` et `sémantique` d’un texte.

# %% [markdown]
# ## Un petit historique
#
# 📌 1987 — Établissement de la *Text Encoding Initiative*
#
# 📌 1990 — TEI P1, dir. Michael Sperberg-McQueen et Lou Burnard
#
# 📌 1992-93 — TEI P2, expansion
#
# 📌 1994 — TEI P3, première version complète
#
# 📌 2000 — Naissance du *TEI Consortium*
#
# 📌 2001-04 — TEI P4, introduction du XML
#
# 📌 2007 — TEI P5, abandon du SGML

# %% [markdown]
# ## Principe de Poughkeepsie (1987)
#
# 1. Provide a standard format for data interchange in humanities research
# 2. Suggest principles for the encoding of texts in the same format
# 3. Define a recommended syntax for the format and a metalanguage for the description of text-encoding schemes : describe the new format and representative existing schemes both in that metalanguage and in prose
# 4. Propose sets of coding conventions suited for various applications
# 5. Include a minimal set of conventions for encoding new texts in the format
# 6. The guidelines are to be drafted by committees on text documentation, text representation, text interpretation and analysis, metalanguage definition and description of existing and proposed schemes, coordinated by a steering committee of representatives of the principal sponsoring organizations
# 7. Compatibility with existing standards will be maintained as far as possible

# %% [markdown]
# ## Penser le texte
#
# La TEI fournit un cadre pour penser la nature du texte : elle constitue une sorte d’encyclopédie de notions textuelles associées à des balises et des règles sur la façon dont elles peuvent être combinées.

# %% [markdown]
# ## Points forts de TEI
#
# 🌟 sémantique : Non pas centré sur la mise en page mais sur le contenu intellectuel.
#
# 🌟 conçu par/pour les chercheurs : Objectif d’aider les chercheurs à créer des ressources textuelles adaptées aux besoins de la recherche.
#
# 🌟 interopérable : Indépendant de tout environnement logiciel, idéal pour l’échange et la collaboration.
#
# 🌟 permet des objectifs d'encodages divers…
#
# - visuel : aspect physique (codicologie, manques, foliotation, etc.) et aspects paléographiques (abréviations et forme développée, etc.)
# - sémantique : toponymes, anthroponymes, dates, balisage des types de discours, désambiguïsation des références textuelles
# - analyique : correspondance des parties du texte à une grille d’analyse (taxonomie, thésaurus, etc.)
#
# 🌟 … et permet d'encoder plus ou moins "proche" du texte

# %% [markdown]
# ## La TEI n'est pas un schéma
#
# TEI (All) n’est pas un schéma à proprement parler, mais plutôt un framework, utile à la conception de son propre schéma.

# %% [markdown]
# ## Aspect modulaire
#
# Les Guidelines de la TEI définissent plusieurs centaines de concepts différents, avec les instructions détaillées sur les éléments qui peuvent être utilisés pour les représenter. La plupart des documents TEI n’a besoin que d’une petite partie de ce qui est fourni. Les projets d’encodage utilisent bien souvent un sous-ensemble très restreint de la TEI : une documentation restreignant l’ensemble utilisé peut être rédigée à l’aide d’outils comme Roma

# %% [markdown]
# ## Ouvrir Oxygen
#
# <figure style="display: flex; align-items: center; justify-content: center;">
#   <img src="media/nouveau.png" alt="logo" style="width: 450px; height: auto;">
# </figure>

# %% [markdown]
# Exercice : encoder un poème
#
# Encoder le poème "Sonnet d'Automne" des *Fleurs du mal* en vous appuyant sur la [documentation TEI pour l’encodage des vers](https://www.tei-c.org/release/doc/tei-p5-doc/fr/html/VE.html).

# %% [markdown]
# C'était pénible ?

# %% [markdown]
# # II. Produire facilement des documents structurés

# %% [markdown]
# ## Les ingrédients
#
# 🥕 du texte avec un balisage léger et sémantique
#
# 🥬 des métadonnées sérialisées
#
# 🍅 une bibliographie structurée
#
# ## La cuisson 🎛️ ♨️
#
# [Pandoc](https://pandoc.org/)
#
# <figure style="display: flex; align-items: center; justify-content: center;">
#   <img src="media/pandoc-cartoon.svg" alt="logo" style="width: 450px; height: auto;">
# </figure>

# %% [markdown]
# # Langage de balisage léger

# %% [markdown]
# ## Markdown : exercice
#
# ➡️ TEXTE : pont_mirabeau.txt | IMAGE : pont_mirabeau.png
#
# ➡️ Éditeurs en ligne : [Dillinger](https://dillinger.io/) ou [HedgeDoc](https://demo.hedgedoc.org/)
#
# Faire un encodage en Markdown du poème :
#
# - mettre le titre en niveau 1
# - recréer les strophes et les vers
# - créer une ligne de séparation avant le début du poème
# - mettre le chapeau en italique
# - mettre les noms propres en gras
# - mettre le titre des recueil en italique
# - insérer une image
# - insérer des liens vers les pages Wikidata de Appolinaire et de Alcool
#
#
# BONUS de pirate 🏴‍☠️🦜 (on fait ça ensemble) : insérer du HTML pour mettre les refrains en couleur

# %% [markdown]
# ## Il existe d'autres langages de balisage similaires à Markdown
#
# - reStructuredText (dénoté par le suffixe de nom de fichier .rst)
# - AsciiDoc (.adoc)
# - MediaWiki, la plateforme utilisée par Wikipédia utilise son propre langage de balisage
# - djot
# - …

# %% [markdown]
# # Les formats de sérialisation des métadonnées

# %% [markdown]
# ## JSON (*JavaScript Object Notation*)
#
# { } une structure similaire aux aux dictionnaires en Python
#
# { } un objet `{}` vs. une liste `[]`
#
# { } le séparateur est la virgule
#
# { } chaque `clé` est associée à une `valeur` séparés par une virgule
#
# { } la structure peut fonctionner en arborescence, à plusieurs niveaux
#
# ```
# [
# {"Id_Monographie":"001a", "Id_Enqueté":"001aE1", "Serie_Tome":"1-1 (1857)", "Prénom":"Jean", "Nom":"M**", "Place dans la famille":"Père", "Lieu de naissance":"T** (Aube)"},
#
# {"Id_Monographie":"001a", "Id_Enqueté":"001aE2", "Serie_Tome":"1-1 (1857)", "Prénom":"Marie", "Nom":"R**", "Place dans la famille":"Mère", "Lieu de naissance":"L** (Meurthe)"},
#
# {"Id_Monographie":"001a", "Id_Enqueté":"001aE3", "Serie_Tome":"1-1 (1857)", "Prénom":"Joseph", "Nom":"M**", "Place dans la famille":"Fils", "Lieu de naissance":""}
# ]
# ```

# %% [markdown]
# ## exercice : ta bibliothèque personnelle en JSON
#
# Créer un fichier JSON représentant ta collection de livres avec différents niveaux de complexité.
#
# 🔧 [Des exemples de livre ici.](https://www.babelio.com/liste/10466/Les-100-romans-les-plus-lus)
#
# 🔧 [Un éditeur/validateur de JSON en ligne.](https://jsoneditoronline.org/)
#
# ✍️ exercice 1 : un livre simple
#
# Créer un objet JSON représentant un seul livre avec ces informations :
#
# - Titre
# - Auteur
# - Année de publication
# - Nombre de pages
# - Lu ou pas (booléen)

# %% [markdown]
# Besoin d'un indice ?
#
# ```json
# {
#   "titre": "...",
#   "auteur": "...",
#   ...
# }
# ```

# %% [markdown]
# ✍️ exercice 2 : plusieurs livres
#
# Transformer ton JSON pour avoir une liste de 3 livres minimum.

# %% [markdown]
# ✍️ exercice 3 : enrichir les données
#
# Pour chaque livre, ajouter :
#
# - une liste de catégories/genres
# - un objet "notes" contenant
#     - une note sur 5
#     - un commentaire personnel (peut être null si pas de commentaire)

# %% [markdown]
# ✍️ exercice 4 : structure complète
#
# Englober la liste de livres dans un objet principal qui contient :
#
# - un champ "proprietaire" (ton nom)
# - un champ "livres" (ta liste)
# - un champ "statistiques" avec :
#     - nombre total de livres
#     - nombre de livres lus

# %% [markdown]
# ## XML — exemple du protocole OAI-PMH (*Open Archives Initiative - Protocol for Metadata Harvesting*)
#
# ⛃ échanges de données entre différents systèmes informatiques
#
# ⛃ aggréger les catalogue des bibliothèques
#
# exemple : [arXiv](https://oaipmh.arxiv.org/oai?verb=ListRecords&metadataPrefix=oai_dc)
#
# ⛃ une API REST : vous tapez une URL dans votre navigateur et un serveur vous renvoie des données (en XML, en l'occurence)
#
# `[URL_BASE] ? verb=[VERBE] & [PARAMETRE1]=[VALEUR1] & [PARAMETRE2]=[VALEUR2]`
#
# <figure style="display: flex; align-items: center; justify-content: center;">
#   <img src="media/OAIPMH.png" alt="logo" style="width: 300px; height: auto;">
# </figure>

# %% [markdown]
# ## exercice : jouer avec l'API OAI-PMH de ArXiv
#
# ✍️ exercice 1 : lister les formats de métadonnées de l'entrepôt OAI-PMH d'ArXiv
#
# https://oaipmh.arxiv.org/oai?verb=ListMetadataFormats
#
# ❓ combien de formats de métadonnées sont disponibles ?
#
# ❓ listez-les avec leur préfixe (`<metadataPrefix>`)
#
# `format de métadonnées` = les règles (des balises et des règles pour les utiliser) pour échanger des métadonnées de manière uniforme
#
# > L’objectif du Dublin Core est de fournir un socle commun d’éléments descriptifs pour améliorer le signalement et la recherche de ressources au-delà des diverses communautés et des nombreux formats descriptifs propres à chaque spécialité, tout en restant suffisamment structuré. (https://www.bnf.fr/)

# %% [markdown]
# ✍️ exercice 2 : lister les collection de l'entrepôt OAI-PMH d'ArXiv
#
# https://oaipmh.arxiv.org/oai?verb=ListSets
#
# - expliquer / décomposer l'URL et identifier la requête à l'API
# - repérer les identifiants des collections ? (ex: cs, math, physics)

# %% [markdown]
# Indice : chaque `<setSpec>` contient l'identifiant à utiliser

# %% [markdown]
# ✍️ exercice 3 : consulter les items d'une certaine collection
#
# - choisir une collection
# - changer le verbe de `ListSets` pour `ListRecords`
# - ajouter le paramètre `metadataPrefix=oai_dc`
# - ajouter le paramètre set=`[identifiant de la collection, par exemple cs pour "Computer Science"]`
#
# ---
#
# 🃏 cheatsheet
#
# `https://oaipmh.arxiv.org/oai?verb=[VERBE]&metadataPrefix=[FORMAT]&set=[COLLECTION]&from=[DATE]`

# %% [markdown]
# ✍️ exercice 4 : ajouter un filtre pour consulter les items de cette collection depuis décembre 2024
#
# ---
#
# 🃏 cheatsheet
#
# `https://oaipmh.arxiv.org/oai?verb=[VERBE]&metadataPrefix=[FORMAT]&set=[COLLECTION]&from=[DATE]`
#
# ⚠️ format de la date : AAAA-MM-JJ

# %% [markdown]
# ✍️ exercice 5 : récupérer tous les articles de mathématiques depuis janvier 2025
#
# ---
#
# 🃏 cheatsheet
#
# - lister les collections
# - chercher l'identifiant à utiliser
# - choisir le bon verbe pour
# - https://oaipmh.arxiv.org/oai?verb=[VERBE]&metadataPrefix=[FORMAT]&set=[COLLECTION]&from=[DATE]

# %% [markdown]
# Bonus :
#
# https://oaipmh.arxiv.org/oai?verb=ListRecords&metadataPrefix=oai_dc&set=math&from=2024-12-01
#
# ❓ *j'ai accès à quoi ?*

# %% [markdown]
# ✍️ exercice 6 : récupérer les métadonnées d'un item précis
#
# Trouve ton identifiant :
#
# 🗂️ sortir la liste de tous les items avec leurs identifiants en changeant le verbe
#
# 🗝️ indice : ListIdentifiers
#
# 🗂️ sortir la liste de tous les items sur une plage de date
#
# 🗂️ sortir la liste de tous les items par catégorie
#
# 🗂️ faire une combinaison : la liste de tous les articles en maths et depuis janvier 2024
#
# 🗂️ choisir un identifiant
#
# 🗂️ construire une url pour accéder aux métadonnées de cet enregitrement
#
# ---
#
# 🃏 cheatsheet
#
# https://oaipmh.arxiv.org/oai?verb=GetRecord&identifier=IDENTIFIER&metadataPrefix=FORMAT

# %% [markdown]
# ❓ quel est le titre de cet article ?
#
# ❓ qui sont les auteurs ?
#
# ❓ à quelle date a-t-il été publié ?
#
# ❓ quel est le résumé (description) de l'article ?
#
# ✍️ exercice 6 : récupérer le même article en format arXiv
#
# ❓ quelles informations supplémentaires trouvez-vous dans ce format par rapport au Dublin Core ?

# %% [markdown]
# 📖 Ressources utiles
#
# Documentation OAI-PMH : https://www.openarchives.org/OAI/openarchivesprotocol.html
#
# Documentation arXiv : https://info.arxiv.org/help/oa/index.html

# %% [markdown]
# ## YAML
#
# ⚙️ *Yet another markup language* (1.0) ou *Yaml ain’t markup language* (depuis 1.1)
#
# ⚙️ se distingue par sa lisibilité
#
# ⚙️ repose sur l'indentation (attention pas de tabulation !)
#
# ⚙️ sert à créer des fichiers de configuration
#
# ```
# ---
# title: "Les _mémoires_ de Fairfax"
# date: "2026-02-03"
# authors:
#   - forename: Thomas
#     surname: Fairfax
# controlledKeywords:
#   - idRameau: ''
#     label: Archives
#     uriRameau: http://data.bnf.fr/ark:/12148/cb13318572g
# ---
# ```

# %% [markdown]
# # Structurer une bibliographie

# %% [markdown]
# ## Données vs. style biblio
#
# 1. La référence = donnée
#
# Quand on est dans des pratiques de recherche et qu'on veut présenter ses sources, il y a deux actes différents : la citation à l'intérieur du texte et le fait de créer une bibliographie, qui constitue la liste des références à qu'on a utilisées à la fin du document.
#
# Les références bibliographiques = des données
#
# ```
# ┌─────────────────────────────────────┐
# │  FICHE CATALOGUE 📇                 │
# ├─────────────────────────────────────┤
# │ Cote: 801.95 GEN                    │
# │ Auteur: GENETTE, Gérard             │
# │ Titre: Figures III                  │
# │ Éditeur: Seuil                      │
# │ Année: 1972                         │
# │ Pages: 285 p.                       │
# │ Collection: Poétique                │
# │ ISBN: 2-02-002351-5                 │
# └─────────────────────────────────────┘
# ```
#
# Si ces données sont bien structurées, on peut les `réutiliser`, les `formater` (présenter) de plusieurs manière, et les `exposer`.

# %% [markdown]
# ## Données vs. style biblio
#
# 2. Le style bibliographique = la présentation des données
#
# Les revues scientifique, les maisons d'édition ou les universités imposent des contraintes dans la présentation des références bibligraphiques (citation ou bibliographie).
#
# Un style bibliographique = un ensemble de règles pour mettre en forme la référence bibliographique.
#
# **Style APA (7e édition)**<br/>
# Genette, G. (1972). *Figures III*. Éditions du Seuil.
#
# **Style MLA (9e édition)**<br/>
# Genette, Gérard. *Figures III*. Éditions du Seuil, 1972.
#
# **Style Chicago (english)**<br/>
# Genette, Gérard. *Figures III*. Paris: Éditions du Seuil, 1972.

# %% [markdown]
# Il faut donc produire une balisage pour identifier tous les éléments d'une référence bibliographique.
#
# ```
# DONNÉES (contenu)          STYLE (présentation)
#      ↓                            ↓
# [Base de données]    →    [Règles de formatage]
#                                    ↓
#                           [Référence formatée]
# ```

# %% [markdown]
# ## Le format BibTeX
#
# ```
# @book{genette1972,
#   author = {Genette, Gérard},
#   title = {Figures III},
#   publisher = {Éditions du Seuil},
#   address = {Paris},
#   year = {1972}
# }
# ```

# %% [markdown]
# ## Autres formats de références bibliographiques
#
# - CSL-JSON
# - RIS
# - Endnote XML
# - TEI
# - RDF
#
# On ne va pas créer ça avec nos petites mains 😅

# %% [markdown]
# ![zozo](media/Screenshot-2025-06-19-at-10.48.46-1200.png)
#
# 𝘇 logiciel et service de stockage en ligne pour la gestion des références bibliographiques
#
# 𝘇 logiciel libre et collaboratif via le service en ligne
#
# 𝘇 permet la constitution et le partage des bibliographies

# %% [markdown]
# ## Zotero
#
# 𝘇 collecter les références bibliographiques en ligne (importance des données structurées !) via un plug-in à installer dans votre navigateur
#
# 𝘇 organiser les références dans des bibliothèques / collections / sous-collections
#
# 𝘇 indexation transversale via des marqueurs et des tags
#
# 𝘇 citer les références dans des documents (markdown, LaTeX, Word…)
#
# 𝘇 stockage et partage

# %% [markdown]
# # Chaîne de transformation

# %% [markdown]
# ## Rappel : structurer
#
# 💡 donner du sens au texte
#
# 💡 séparation du fond et de la forme
#
# 💡 le balisage choisit dépend de ce qu'on veut faire avec le document
#
# ```
# 📝 MARKDOWN         |         🎨 HTML             |        🗂️ XML
# (écriture)          |        (affichage)          |       (données)
#                     |                             |
# # Titre             |        <h1>Titre</h1>       |     <titre niveau="1">
# [Maupassant]{.pers} |        <spans class="pers"> |     <persName>Maupassant</persName>
#                     |                             |
# Humain d'abord      |        Navigateur web       |     Machine-readable
# Facile à écrire     |        Style CSS            |     Facile à traiter
# ```

# %% [markdown]
# ## Conversion
#
# 👉 un document structuré peut être lu par la machine, qui peut reconstruire cette struture dans un autre langage de balisage
#
# ```
# .md  →  [Parser]  →  [AST]  →  [Generator]  →  .html
#  📄        🔧         🌳          ⚡            </>
# ```

# %% [markdown]
# ## Pandoc
#
# - logiciel de conversion de fichiers texte
# - libre, sous licence GPL → une communuaté se crée autour de l'outils et des pratiques
# - il est développé en Haskel à l'initiative d'un professeur de philosophie John MacFarlane
# - utilisé en ligne de commande (on est capable)
# - commande de base : `pandoc [options] fichier.entree` (produit du HTML par défaut)
# - les paramètres de la conversion : le texte balisé, les métadonnées sérialisées, et la bibliographie structurée
#
# ```
#                         ┌──→  🎨 HTML
#                         │     (présentation web)
#                         │
# 📝 Markdown        ─────┼──→  🗂️ XML
#   (source, lisible,     │     (structuré, sémantique,
#   portable)             │      interrogeable, échangeable)
#                         │
#                         └──→  📄 PDF ou autres...
# ```

# %% [markdown]
# ## Installation
#
# 🔧 **installer pandoc** [suivre les instructions de la doc](https://docs.zettlr.com/fr/installing-pandoc/).
#
# 🔧 **ouvrir un terminal dans vscode : terminal > new terminal**
#
# ![terminal](media/terminal.png)
#
# 🔧 **travailler dans un dossier dédié**
#
# `mkdir test-pandoc` (*make directory*)
#
# `cd test-pandoc` (*change directory*)
#
# `code -r .` (*ouvre ce dossier (.) dans vscode en **r**étutilisant la fenêtre*)s

# %% [markdown]
# ## exercice 1
#
# ✍️  créer un document Markdown avec des niveaux de titre, une liste, une citation longue et de l’emphase (italique et gras)
#
# ✍️  lancer la commande `pandoc mon-fichier.md`
#
# Que remarquez-vous ? 🧐

# %% [markdown]
# Il faut l'option `-o` pour créer un fichier

# %% [markdown]
# ## exercice 2 : découvrir les options
#
# ✍️  lancer une commande plus verbeuse : `pandoc -f markdown -t html mon-fichier.md -o mon-fichier.html`
#
# Que remarquez-vous ? 🧐

# %% [markdown]
# On n'a que le texte, or on a besoin de métadonnées.

# %% [markdown]
# ## exercice 3 : ajouter des métadonnées
#
# ✍️ ajouter un entête en YAML, en haut du document, signalé par trois tirets :
#
# ```
# ---
# title: Le titre de mon document
# author: Mon Nom
# ---
# ```
#
# ⚠️ attention au YAML
#
# - pas de tabulation pour l'indentation, uniquement des espaces
# - pour chaque champ il faut : une clé, deux-points bien collés, valeur du champ

# %% [markdown]
# ✍️ transformer en html : `pandoc -f markdown -t html mon-fichier.md -o mon-fichier.html -s`
#
# L'option `-s` pour `standalone` génère un fichier HTML complet avec `<head>`, `<body>`, et intègre les métadonnées YAML comme le `<title>` et les balises `<meta>` correspondantes.
# Sans `--standalone`, Pandoc produit juste un fragment HTML et ignore le YAML.
#
# ✍️ transformer en .docx : `pandoc -f markdown -t docx mon-fichier.md -o mon-fichier.docx`

# %% [markdown]
# # Découverte de LaTeX

# %% [markdown]
# ## Histoire et principes
#
# 🇱 1978 — Donald Knuth initiative du langage TEX (/tɛx/ : tau, epsilon, chi (τεχ)) pour éditer son œuvre majeure *The Art of Computer Programming*
#
# 🇱 un langage et un système de composition de documents, grande précision typographique
#
# 🇱 logiciel libre et gratuit
#
# 🇱 1984 — LaTeX : simplification par Leslie Lamport
#
# 🇱 utilisé dans le domaine des sciences car on peut facilement écrire des formules mathématiques
#
# 🇱 pas des balises sémantiques mais des commandes `\chapter{Titre de chapitre}`

# %% [markdown]
# ## Syntaxe
#
# Exemple minimal :
#
# ```
# \documentclass{book}
# %% Préambule %%
#
# \begin{document}
# %% Corps du document %%
#
# \chapter{Titre de chapitre}
# Certaines \textbf{découvertes} \underline{scientifiques}
# sont le produit du \textbf{\textit{hasard}}.
#
# \end{document}
# ```

# %% [markdown]
# ## Résistance aux traitements de texte ?
#
# > TeX resulted in a worldwide community of users, developers, and user groups evolved, largely  disconnected from the more conventional desktop publishing world driven by commercial concerns  of publishers and desktop publishing system vendors (so very different than Knuth’s concerns for TeX).
# >
# > — Beeton, Berry, and Walden 2018 Beeton, Barbara, Karl Berry, and David Walden. « TEX: A Branch in Desktop Publishing Evolution, Part 1. » *IEEE Annals of the History of Computing* vol. 40.3 (2018): 78–93.

# %% [markdown]
# ## Manipulation
#
# rendez-vous sur [Overleaf](https://www.overleaf.com/)
#
# new project > upload project > verser exercicesLaTeX.zip
#
# dans le projet > ⚙️ settings > compiler
#
# ![compiler](media/compiler.png)

# %% [markdown]
# ## Taper en LaTeX
#
# - le nombre d'espaces ne change rien
# - un retour à la ligne = un espace
# - un tilde (`~`) = espace insécable
# - deux retours à la ligne ou plus = nouveau paragraphe
# - `--` = demi-cadratin, `---` = cadratin
# - pour taper des points de suspensions: `\dots`
# - tout ce qui suit le caractère `%` est un commentaire
# - attention, certains caractères sont utilisés par LaTeX: `\ ~ ^ { } % _ & $ #`. Pour insérer ces caractères dans un texte, il faut taper: `\textbackslash  \textasciitilde \textasciicircum \{ \} \% \_ \& \$ \#`

# %% [markdown]
# ## Le préambule
#
# ```
# \documentclass[12pt,a4paper]{article} %appel de classe
# %appel des packages:
# \usepackage{fontspec} %package pour gérer les fontes
# \usepackage{xunicode} %package pour gérer l'unicode
# \usepackage{polyglossia} %package pour gérer les langues
# \setmainlanguage{french}
#
# %d'autres packages peuvent être appelés ici
# %des commandes et des environnements peuvent être (re)définis ici
#
# \begin{document}
# corps du texte
# \end{document}
# ```

# %% [markdown]
# ## L'appel de classe
#
# - Quelques classes possibles: `article book beamer memoir`
# - Quelques options possibles de l'appel de classe:
#
# |option|effet|
# |---   |-----  |
# |`10pt`| pour une police de base en 10 pt|
# |`11pt`| pour une police de base en 11 pt|
# |`12pt`| pour une police de base en 12 pt|
# |`onecolumn`| pour un texte sur une seule colonne (par défaut pour les classes présentées)|
# |`twocolumn`| pour un texte sur deux colonnes|
# |`oneside`| pour une impression en recto seulement|
# |`twoside`| pour une impression en recto-verso|
# |`notitlepage`| pour ne pas avoir de page de titre spécifique (par défaut pour la classe `article`)|
# |`titlepage`| pour avoir une page de titre spécifique par défaut pour la classe `book`|

# %% [markdown]
# ✍️ exercice 1

# %% [markdown]
# ## Les packages
#
# - `Package` = code permettant de définir un ensemble de commandes orienté vers utilisation spécifique. L'ensemble de ce code est contenu dans un fichier avec l'extension `.sty`
# - Appeler un package : dans le préambule, `\usepackage{nom_du_package}`
# - Obtenir la documentation : taper dans un terminal `texdoc nom_du_package`

# %% [markdown]
# ✍️ exercice 2

# %% [markdown]
# ## Les commandes
#
# - `Commande` = bout de code qui va être interprété par le compilateur.
# - `Argument`= paramètre passé à une commande et qui en modifie le comportement ou qui indique ce sur quoi elle  doit s'appliquer .
# - Syntaxe d'une commande
#
# 1. backslash (`\`) + nom de la commande
# 2. entre crochets : arguments optionnels
# 3. entre accolades : arguments obligatoires
#
# exemple : pour insérer une image on écrirait :
#
# `\includegraphics[width=0.5\textwidth]{media/image.png}`

# %% [markdown]
# ## Faire apparaître le titre du document
#
# - dans le préambule: `\title{titre_du_document} \author{auteur_du_document} \date{date_du_document}` (pour qu'un de ces éléments n'apparaisse pas, laisser l'argument vide. Par défaut, si elle n'est pas indiquée, la date est celle du jour)
# - dans le corps du document `\maketitle`

# %% [markdown]
# ## Commandes de section
#
# |Commande| Sens| Numéro de niveau|
# |-- |-- |-- |
# |`\part{ton_titre}`| Titre de partie| -1|
# |`\chapter{ton_titre}`| Titre de chapitre| 0|
# |`\section{ton_titre}`| Titre de section| 1|
# |`\subsection{ton_titre}`| Titre de sous-section| 2|
#
# - pour faire apparaître la table des matières : `\tableofcontents`
# - `\part` et `\chapter` provoquent un changement de page (classe `book` seulement)

# %% [markdown]
# ✍️ exercice 3

# %% [markdown]
# ## Les environnements
#
# - `environnement` = portion de document qui a une signification spécifique et subit un traitement spécifique. L'environnement accepte le saut de paragraphe. On peut utiliser des commandes au sein d'environnements.
# - syntaxe d'un environnement = `\begin{nom_de_l_environnement} \end{nom_de_l_environnemen}`. Tout ce qui se trouve entre ces deux balises est à l'intérieur de l'environnement.
#
# exemple : l'environnement `abstract` de la classe `article`
#
# ```
# \begin{abstract}
#     Emma Bovary, une jeune femme rêveuse mariée à un médecin de campagne ennuyeux, cherche à échapper à sa vie monotone à travers des liaisons adultères et des dépenses extravagantes. Son idéalisme romantique et ses désillusions la mènent progressivement à la ruine financière et au suicide.
# \end{abstract}
# ```

# %% [markdown]
# ✍️ exercice 4
#
# Structurer le lorem ipsum pour que le document compilé en sortie ressemble au modele.

# %% [markdown]
# 📖 Ressources utiles
#
# - [Séries de leçon sur LaTeX (Zeste de Savoir)](https://zestedesavoir.com/tutoriels/826/introduction-a-latex/)
# - [Tutoriel d'Overleaf pour LaTeX](https://www.overleaf.com/learn/latex/Learn_LaTeX_in_30_minutes)

# %% [markdown]
# ## Bibliographie
#
# Burnard, Lou. 2015. « La TEI et le XML ». In *Qu’est-ce que la Text Encoding Initiative ? Encyclopédie numérique.* OpenEdition Press. https://doi.org/10.4000/books.oep.1298.
#
# Fauchié, Antoine. 2020. « Fabriques de publication : Pandoc ». quaternum.net, avril 30. https://www.quaternum.net/2020/04/30/fabriques-de-publication-pandoc/.
#
# Karnaj, et ToxicScorpius. 2020. « Introduction à LaTeX ». *Text. Zeste de Savoir*, mars 13. https://zestedesavoir.com/tutoriels/826/introduction-a-latex/.
#
# Perret, Arthur. 2021. « L’écriture académique au format texte ». septembre 21. https://www.arthurperret.fr/cours/2021-09-21-ecriture-academique-format-texte.html.
#
# Tenen, Dennis, et Grant Wythoff. 2014. « Rédaction durable avec Pandoc et Markdown ». *Programming Historian*, mars 19. https://programminghistorian.org/fr/lecons/redaction-durable-avec-pandoc-et-markdown.
#
# Rouquette, Maïeul. 2012. *(Xe)LaTeX appliqué aux sciences humaines*. Atramenta. https://shs.hal.science/halshs-00924546.
