# %% [markdown]
# # Introduction à l'édition numérique
#
# 📌 Université de Rouen, Licence 3 Édition et Création littéraire, 2026
#
# ---
#
# Clara Grometto
#
# 📫 clara.grometto@univ-rouen.fr -- gromettoclara@gmail.com
#
# 💼 Doctorante en Humanités Numériques @ Université de Rouen Normandie & Université de Montréal
#
# <figure style="display: flex; align-items: center; justify-content: center;">
#   <img src="media/logo.png" alt="logo" style="width: 450px; height: auto;">
# </figure>

# %% [markdown]
# ## Objectifs du cours
#
# 🏆 Comprendre ce qu'est un document sur un ordinateur
#
# 🏆 Savoir différencier les catégories de fichiers et les standards et formats qui leur sont associés
#
# 🏆 Savoir différencier la mise en forme d'un fichier et sa structuration sémantique et se familiariser avec des outils permettant de travailler au plus près de la structure sémantique du texte
#
# 🏆 Connaître théoriquement plusieurs modes d'organisation et de mise en forme d'un fichier textuel (XML, Markdown, LaTeX, ...) et utiliser des outils de conversion pour prendre en main des chaînes éditoriales
#
# 🏆 S'initier aux pratiques éditoriales adaptées et pérennes dans l'environnement numérique
#
# 🏆 Comprendre les enjeux culturels, techniques et politiques des choix éditoriaux numériques

# %% [markdown]
# ## Programme et calendrier
#
# - Séance 1-2 : Le texte numérique, aspects théoriques et techniques
#
# - Séance 3-4 : Le document numérique, aspects théoriques et techniques
#
# - Séance 5-6 : Produire des documents structurés
#
# - Séance 7 : Fabriquer des sites web et collaborer
#
# - Séance 8-9-10 : TD / projet
#
# - Séance bonus 11 : LaTeX pour les textes anciens
#
# - Séance bonus 12 : XML-TEI -- approfondissement

# %% [markdown]
# ## Modalités d'évaluation
#
# - Mise en œuvre (bricolage) collectif d'une mini-chaîne de conversion de document qui donnera lieu au déploiement d'un blog
# - Note individuelle sur la base de :
#     - Une contribution écrite en markdown
#         - Maîtrise de la syntaxe
#         - Qualité de la structuration sémantique
#     - Documentation du processus
#         - Réflexion sur les choix techniques du groupe
#         - Travail écrit dans un format ouvert
#         - Le fond et la forme sont notés

# %% [markdown]
# ## Un travail collectif en TD, guidé et PAS NOTÉ
#
# - choix d'un outil pour la collaboration
# - choix du format d'encodage des sources
# - choix de l'outil pour créer un blog
# - personnalisation graphique

# %% [markdown]
# ## Ce que ce cours est
#
# <div style="font-size: 6rem; text-align: center;">
# 💭 💬 😎 🔥
# </div>

# %% [markdown]
# ## Ce que ce cours n'est PAS
#
# <div style="font-size: 6rem; text-align: center;">
# 😵 🔨 0️⃣ 💀
# </div>

# %% [markdown]
# Je suis là pour vous !! 📧

# %% [markdown]
# # Chapitre 1 : Le texte -- l'écriture numérique

# %% [markdown]
# # Le texte -- l'écriture numérique : aspects théoriques

# %% [markdown]
# ## Brainsto : pour vous qu'est-ce que ça change d'écrire sur une machine ?

# %% [markdown]
# ## Intermédiaire(s)
#
# > "une large partie des œuvres de la communication contemporaine ne se laisse saisir que par la médiation d'un appareillage technique plus ou moins complexe. Il s'agit de dispositifs de lecture sans lesquels l'accès au message est impossible" (D. Cotte, Le concept de « document numérique », 2004)

# %% [markdown]
# Roch Delannay (2025. « L’écriture numérique ou le soliloque parallèle ») parle d'un trouble qui :
#
# > "naît de la rencontre entre une représentation culturelle du texte, structurée graphiquement et une représentation du texte structurée par le texte, comme pour une page Web interprétée par un navigateur et son pendant au format HTML."

# %% [markdown]
# ## Point terminologique
#
# `Numérique :`
#
# - fait référence au domaine informatique (automatique + information)
# - renvoie à la nature matériel du document : "électronique"
#
# `Électronique :`
#
# - un composant matériel électronique ne répond qu'en terme de "on/off" (courant électrique)
# - représentation binaire : On = 1, Off = 0
#
# `Écriture :`
#
# inscription (trace dans la matière) + interprétation (un système de signe partagé qui dépasse cette trace) (Christin, 1999 ; Pédauques, 2O06)

# %% [markdown]
# ## LES écritures numériques
#
# ![couches](media/couches.png)

# %% [markdown]
# Il est nécessaire de distinguer le plan matériel (hardware) et immatériel (software).
#
# ![hardsoft](media/coursedition.drawio.png)
#
# - contenu encodé sous la forme de suites de 0 et de 1
# - matérialisé virtuellement sous la forme d'un fichier
# - c'est grâce à la médiation d'un logiciel qu'on y a accès
#
# Si vous êtes intéressé.e.s par le fonctionnement d'un disque dur [c'est par ici 🔗](https://www.youtube.com/watch?v=bMSXQhra6hY)

# %% [markdown]
# ## L'accès au texte numérique se fait via d'autres textes qui encadrent et structurent l'écriture
#
# Le concept d'`architexte` nous vient de Jeanneret et Souchier (1999)
#
# > "On a fait une comparaison avec le stéréotype, le stéréotype qui était un objet technique inventé à la fin du XVIIe siècle, et qui, lui, reproduit exactement le même texte. Le rôle du stéréotype est d’éviter d’avoir à recomposer les caractères, et donc on « cliche », et avec le cliché on va refaire toujours le même texte. Mais le stéréotype reproduit en même temps la forme et l’occurrence du texte et aucune des deux ne bouge. Dans l’architexte, en tant que plastigramme — forme d’écriture plastique, souple —, on reproduit constamment les mêmes formes mais avec des énonciations textuelles différentes, des occurrences textuelles différentes." (Bazet, Isabelle, Florian Hémont, et Anne Mayère. 2017. « Entretien avec Yves Jeanneret ». Communication. Information médias théories pratiques, nᵒ vol. 34/2 (juillet). https://doi.org/10.4000/communication.7287)
#
# Il y a donc différentes *couches* d'écriture, il y a des intermédiaires fait décriture entre la première couche et le texte tel qu'il s'affiche à l'écran.

# %% [markdown]
# ## Écriture numérique
#
# - passage à l'unité atomique et discrète 0️⃣1️⃣
# - tous les médias sont manipulables comme du texte : sous la surface apparente de l'écran, ces médias encodent et décodent les mêmes caractères binaires 0 et 1
#
# ## Ce qui implique que les médias numériques sont
#
# - `variables` -- réinscription du support (Bouchardon 2014)
# - `calculables` -- la représentation numérique permet de faire un certain nombre d'opération avec et sur le texte ([comprendre la vectorisation](https://demo-atelier.streamlit.app/))
# - rupture entre le geste d'écriture et l'inscription sur le support

# %% [markdown]
# # Le texte -- l'écriture numérique : aspects techniques
#
# ## L'encodage des caractères : des binaires à l'affichage sur un écran

# %% [markdown]
# ## Le texte brut
#
# Définition : du texte au kilomètre, sans indication de structure ou de mise en forme.
#
# - le texte numérique est une suite de _bits_, c'est-à-dire de 0 et de 1
# - le flux de bits est découpé en octets, séquences de 8 bits
# - il y a 2⁸ combinaisons possibles de 0 et de 1 pour former un octet, c'est-à-dire 256 nombres en notation binaire. Donc 8 bits correspondent aux chiffres de 0 à 255
# - chaque nombre est interprété comme un numéro d'ordre dans un jeu de caractère
# - la succession des caractère forme le texte
#
# Pour l'ordinateur un texte ce n'est rien d'autre qu'une suite de nombre entre 0 et 257.

# %% [markdown]
# Tout document conservé sur un ordinateur est constitué d'une série de 0 et de 1
#
# Comment passe-t-on d'une suite de 0 et de 1 à un texte ou une image sans se tromper dans l'interprétation ?
#
# ➡️ Grâce aux normes d'encodage !
#
# 🗝️ Les `normes d'encodages` = clefs d'encodage/décodage pour passer d'une forme intelligible pour les humains à une forme lisible par la machine
#
# 🗝️ En fonction du type de fichier encodé (texte, image, vidéo, etc.), il existe différents paysages de normes et de modes de représentation

# %% [markdown]
# ## Mauvais encodage/décodage
#
# Si on n'utilise pas la bonne clef d'encodage ou de décodage d'un texte, on risque d'obtenir un texte partiellement ou entièrement illisible.
#
# ### UTF-8 ouvert avec 8859-1 (Latin 1)
#
# La Joconde, ou Portrait de Mona Lisa, est un tableau de l'artiste LÃ©onard de Vinci, rÃ©alisÃ© entre 1503 et 1506 ou entre 1513 et 15161,2, et peut-Ãªtre jusqu'Ã  1519 (l'artiste Ã©tant mort cette annÃ©e-lÃ , le 2 mai)3, qui reprÃ©sente un portrait mi-corps, probablement celui de la Florentine Lisa Gherardini, Ã©pouse de Francesco del Giocondo. Acquise par FranÃ§ois Ier, cette peinture Ã  l'huile sur panneau de bois de peuplier de 77 Ã 53 cm est exposÃ©e au musÃ©e du Louvre Ã  Paris. La Joconde est l'un des rares tableaux attribuÃ©s de faÃ§on certaine Ã  LÃ©onard de Vinci.
#
# ### UTF-8 ouvert avec ISO 8859-5 (Cyrillic)
#
# La Joconde, ou Portrait de Mona Lisa, est un tableau de l'artiste LУЉonard de Vinci, rУЉalisУЉ entre 1503 et 1506 ou entre 1513 et 15161,2, et peut-УЊtre jusqu'У  1519 (l'artiste УЉtant mort cette annУЉe-lУ , le 2 mai)3, qui reprУЉsente un portrait mi-corps, probablement celui de la Florentine Lisa Gherardini, УЉpouse de Francesco del Giocondo. Acquise par FranУЇois Ier, cette peinture У  l'huile sur panneau de bois de peuplier de 77 У 53 cm est exposУЉe au musУЉe du Louvre У  Paris. La Joconde est l'un des rares tableaux attribuУЉs de faУЇon certaine У  LУЉonard de Vinci.

# %% [markdown]
# ## ASCII
#
# 🅰️ *American Standard Code for Information Interchange*
#
# 🅰️ Chaque caractère est représenté par 7 bits empaquetés dans 1 octet
#
# 🅰️ Le jeu de caractères est composé de 95 éléments (pas de caractères accentués) :
#
#  !"#$%&'()*+,-./
# 0123456789:;<=>?
# @ABCDEFGHIJKLMNO
# PQRSTUVWXYZ[\]^_
# `abcdefghijklmno
# pqrstuvwxyz{|}~
#
# 🅰️ Exemple : A = 01000001

# %% [markdown]
# ## ISO 8859-1
#
# 🅰️ C'est la famille sui comprend Latin1 et Western Europe
#
# 🅰️ Chaque caractère est représenté par 8 bits
#
# 🅰️ ISO 8859-1 est rétrocompatible avec ASCII. Le jeu de caractères est composé de 191 éléments : les 95 caractères de la norme ASCII + des symboles et des caractères accentués :
#
#
#  !"#$%&'()*+,-./    ¡¢£¤¥¦§¨©ª«¬-®¯
# 0123456789:;<=>?   °±²³´µ¶·¸¹º»¼½¾¿
# @ABCDEFGHIJKLMNO   ÀÁÂÃÄÅÆÇÈÉÊËÌÍÎÏ
# PQRSTUVWXYZ[\]^_   ÐÑÒÓÔÕÖ×ØÙÚÛÜÝÞß
# `abcdefghijklmno   àáâãäåæçèéêëìíîï
# pqrstuvwxyz{|}~    ðñòóôõö÷øùúûüýþÿ
#
# 🅰️ Exemple : é = 11101001

# %% [markdown]
# ## UTF-8
#
# 🅰️ *Universal Character Set Transformation Format* + base d'encodage (8, 16, 32, ...)
#
# 🅰️ En fonction de la base d'encodage, un caractère peut être représenté par 1, 2, 3 ou 4 octets.
#
# 🅰️ UTF est rétrocompatible avec ASCII, mais pas avec ISO 8859-1. Il s'inscrit dans le cadre établi par Unicode qui vise à faciliter l'échange de textes numériques en assurant leur compatibilité.
#
# 🅰️ Unicode définit plus de 150 000 caractères, issus de multiples alphabets, et prévoit aussi des symboles comme les emojis.
#
# 🅰️ Exemple : 🤓 = 11110000 10011111 10100100 10010011

# %% [markdown]
# ## Avantages du texte brut
#
# - très compressible : légèreté
# - UTF-8 est un standard robuste et largement implémenté, bien bien qu'il assure la plupart du temps une bonne transmission des fichiers d'un système à un autre

# %% [markdown]
# ## Texte brut, texte enrichi
#
# Un fichier de texte peut contenir des indications de mise en forme
#
# - `texte brut` (ou `plain text`) = un texte dépourvu d'information de mise en forme, qui se limite à l'affichage de la traduction des données binaires en caractères alphanumériques et symboles
#
# - `texte enrichi` (ou `rich text`) = un texte qui comporte des éléments de mise en forme, qu'ils soient ou non affichés dans l'interface graphique
#
# ## Éditeur de texte, traitement de texte = deux paradigmes
#
# - `WYSIWYG` (*What You See Is What You Get*) = un `traitement de texte` qui présente un texte enrichi avec sa mise en forme, de manière simultanée
#
# - `WYSIWYM` (*What You See Is What You Mean*) = un `éditeur de texte` qui présente le texte et ses informations de mise en forme sans les interpréter

# %% [markdown]
# ## Conclusion
#
# **Appareillage technique multiple :**
#
# - décodage des éléments electroniques vers des informations numériques
# - interprétation des données binaires
# - affichage
#
# 🅰️ La norme d'encodage d'un texte = une table de correspondance entre un groupe de bits et un caractère alphanumérique ou un symbole
#
# 🅰️ La norme d'encodage définit donc la liste des caractères disponibles (*character set*)
#
# 🅰️ En fonction de la norme, la représentation d'un caractère peut s'étendre sur un ou plusieurs octets
#
# 🅰️ Les normes les plus connues pour des textes en français sont :
#
# - ASCII (1963)
# - ISO 8859-1 (1986)
# - UTF-8 (1996)

# %% [markdown]
# # Et la police de carcatère dans tout ça ?
#
# Une police consiste en un ensemble de définitions de glyphes, c’est-à-dire des formes définies utilisées pour afficher les caractères.
#
# Une fois que votre application est parvenue à déterminer les caractères en jeu, elle consultera les glyphes de la police afin d’afficher ou d’imprimer ces caractères.
#
# ![La police ne possède pas les glyphes correspondant à certains caractères](media/image.png)

# %% [markdown]
# <div style="height: 70vh; overflow-y: auto; padding-right: 10px; padding-bottom: 10px">
#
# ## Biblio
#
# Bazet, Isabelle, Florian Hémont, et Anne Mayère. 2017. « Entretien avec Yves Jeanneret ». *Communication. Information médias théories pratiques*, nᵒ vol. 34/2 (juillet). https://doi.org/10.4000/communication.7287.
#
# Bonaccorsi, Julia. 2012. « Fantasmagories de l’écran ». Habilitation à diriger des recherches, Celsa - Université Paris Sorbonne. https://hal.science/tel-01322308.
#
# Bouchardon, Serge. 2014. « L’écriture numérique : objet de recherche et d’enseignement ». *Les Cahiers de la SFSIC*, janvier 1. https://www.academia.edu/9939686/L_%C3%A9criture_num%C3%A9rique_objet_de_recherche_et_d_enseignement.
#
# Christin, Anne-Marie. 1999. « Les origines de l’écriture:Image, signe, trace ». *Le Débat* 106 (4): 28‑36. https://doi.org/10.3917/deba.106.0028.
#
# Cotte, Dominique. 2004. « Le concept de « document numérique » ». *Communication & Langages* 140 (1): 31‑41. https://doi.org/10.3406/colan.2004.3265.
#
# Delannay, Roch. 2025. « L’écriture numérique ou le soliloque parallèle ». *Terminal. Technologie de l’information, culture & société* 141. https://doi.org/10.4000/148el.
#
# Mellet, Margot. 2020. « Penser le palimpseste numérique. Le projet d’édition numérique collaborative de l’Anthologie palatine ». *Captures : figures, théories et pratiques de l’imaginaire* 5 (1). https://doi.org/10.7202/1073479ar.
#
# Ong, Walter-J., John Hartley, et Hélène Hiessler. 2014. *Oralité et écriture: La technologie de la parole*. Belles Lettres.
#
# Paveau, Marie-Anne. 2013. « Technodiscursivités natives sur Twitter. Une écologie du discours numérique ». *Epistémè : revue internationale de sciences humaines et sociales appliquées / 에피스테메* 9 (juillet): 139‑76.
#
# Souchier, Emmanuël, et Yves Jeanneret. 1999. « Pour une poétique de l’écrit d’écran ». In Xoana. https://hal.science/hal-03761035.
#
# Vitali-Rosati, Marcello. 2020. « Qu’est-ce que l’écriture numérique ? » *Corela. Cognition, représentation, langage*, nᵒ HS-33 (novembre). https://doi.org/10.4000/corela.11759.<br/>
# <br/>
#
# </div>
